# %% [markdown]
# # Library Loader

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../src')
from myConvexHull import *
from sklearn import datasets

# %% [markdown]
# # Test datasets

# %% [markdown]
# Alcohol vs malic acid

# %%
data = datasets.load_wine()

df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target'] = pd.DataFrame(data.target)

plt.figure(figsize = (10, 6))
colors = ['b','r','g']
plt.title('alcohol vs malic acid')
plt.xlabel(data.feature_names[0])
plt.ylabel(data.feature_names[1])

for i in range(len(data.target_names)):
    bucket = df[df['Target'] == i]
    bucket = bucket.iloc[:,[0,1]].values
    lp, rp = getLeftmostAndRightmostPoints(bucket)
    hullPoints = convexHull(lp, rp, bucket)
    plt.scatter(bucket[:,0], bucket[:,1], label=data.target_names[i])
    for simplex in hullPoints:
        plt.plot(simplex[0], simplex[1], color=colors[i])

plt.legend()
plt.show()

# %% [markdown]
# Sepal width vs Length

# %%
data = datasets.load_iris()

df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target'] = pd.DataFrame(data.target)

plt.figure(figsize = (10, 6))
colors = ['b','r','g']
plt.title('sepal width vs length')
plt.xlabel(data.feature_names[0])
plt.ylabel(data.feature_names[1])

for i in range(len(data.target_names)):
    bucket = df[df['Target'] == i]
    bucket = bucket.iloc[:,[0,1]].values
    lp, rp = getLeftmostAndRightmostPoints(bucket)
    hullPoints = convexHull(lp, rp, bucket)
    plt.scatter(bucket[:,0], bucket[:,1], label=data.target_names[i])
    for simplex in hullPoints:
        plt.plot(simplex[0], simplex[1], color=colors[i])

plt.legend()
plt.show()

# %% [markdown]
# Petal width vs Length

# %%
data = datasets.load_iris()

df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target'] = pd.DataFrame(data.target)

plt.figure(figsize = (10, 6))
colors = ['b','r','g']
plt.title('petal width vs length')
plt.xlabel(data.feature_names[2])
plt.ylabel(data.feature_names[3])
for i in range(len(data.target_names)):
    bucket = df[df['Target'] == i]
    bucket = bucket.iloc[:,[2,3]].values
    lp, rp = getLeftmostAndRightmostPoints(bucket)
    hullPoints = convexHull(lp, rp, bucket)
    plt.scatter(bucket[:,0], bucket[:,1], label=data.target_names[i])
    for simplex in hullPoints:
        plt.plot(simplex[0], simplex[1], color=colors[i])

plt.legend()
plt.show()
